# %%
import flickrapi
import json

api_key = u'356c3b8530e59f84095a0afc0da1414d'
api_secret = u'b51150d99cc64044'

#flickr = flickrapi.FlickrAPI(api_key, api_secret)
#for json format
flickr = flickrapi.FlickrAPI(api_key, api_secret, format='parsed-json')

# %%
extras='geo,description,tags'
MacArthurPark = flickr.photos.search(tags='MacArthur Park', per_page=20, extras=extras,format='parsed-json')
photos = MacArthurPark['photos']
from pprint import pprint
pprint(photos)
# Out:
# {'page': 1,
#  'pages': 214,
#  'perpage': 20,
#  'photo': [{'accuracy': 0,
#             'context': 0,
#             'description': {'_content': 'Signed copies of my first book, '
#                                         'titled LONESOME CITY, are available '
#                                         'on my website at <a '
#                                         'href="https://davidingraham.com/book" '
#                                         'rel="noreferrer '
#                                         'nofollow">davidingraham.com/book</a>'},
#             'farm': 66,
#             'id': '51132445243',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'latitude': 0,
#             'longitude': 0,
#             'owner': '59495466@N00',
#             'secret': '20dd9a0c5d',
#             'server': '65535',
#             'tags': 'bw blackwhite losangeles macarthurpark california city '
#                     'iphone iphoneography monochrome mobilephotography '
#                     'squareformat streetphotography urban '
#                     'urbanlifeinmetropolis',
#             'title': 'Across the Street 5'},
#            {'accuracy': 0,
#             'context': 0,
#             'description': {'_content': ''},
#             'farm': 66,
#             'id': '50788075637',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'latitude': 0,
#             'longitude': 0,
#             'owner': '7150652@N02',
#             'secret': 'a63c59e03e',
#             'server': '65535',
#             'tags': 'macarthurpark westlake losangeles california '
#                     'westlaketheatre theater',
#             'title': 'Westlake Theatre'},
#            {'accuracy': 0,
#             'context': 0,
#             'description': {'_content': ''},
#             'farm': 66,
#             'id': '50788074892',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'latitude': 0,
#             'longitude': 0,
#             'owner': '7150652@N02',
#             'secret': '1f4c95d453',
#             'server': '65535',
#             'tags': 'macarthurpark westlake losangeles california statue '
#                     'harrisongrayotis losangelestimes latimes',
#             'title': 'Harrison Gray Otis Statue'},
#            {'accuracy': 0,
#             'context': 0,
#             'description': {'_content': ''},
#             'farm': 66,
#             'id': '50787969751',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'latitude': 0,
#             'longitude': 0,
#             'owner': '7150652@N02',
#             'secret': '07291826a5',
#             'server': '65535',
#             'tags': 'macarthurpark westlake losangeles california park '
#                     'pavilion spanishrevival',
#             'title': 'MacArthur Park Community Arts Center'},
#            {'accuracy': 0,
#             'context': 0,
#             'description': {'_content': ''},
#             'farm': 66,
#             'id': '50787969486',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'latitude': 0,
#             'longitude': 0,
#             'owner': '7150652@N02',
#             'secret': 'a58a5a791e',
#             'server': '65535',
#             'tags': 'macarthurpark westlake losangeles california elksbuilding '
#                     'elks themacarthur hotel',
#             'title': 'Elks Building'},
#            {'accuracy': 0,
#             'context': 0,
#             'description': {'_content': ''},
#             'farm': 66,
#             'id': '50787231266',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'latitude': 0,
#             'longitude': 0,
#             'owner': '7150652@N02',
#             'secret': 'dd83056b0f',
#             'server': '65535',
#             'tags': 'westlake losangeles california unionhall uclalaborcenter '
#                     'macarthurpark',
#             'title': 'Unite!'},
#            {'accuracy': 0,
#             'context': 0,
#             'description': {'_content': ''},
#             'farm': 66,
#             'id': '50787230516',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'latitude': 0,
#             'longitude': 0,
#             'owner': '7150652@N02',
#             'secret': '5cc2707a35',
#             'server': '65535',
#             'tags': 'westlake losangeles california macarthurpark cityscape',
#             'title': 'MacArthur Park'},
#            {'accuracy': 0,
#             'context': 0,
#             'description': {'_content': ''},
#             'farm': 66,
#             'id': '50787229971',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'latitude': 0,
#             'longitude': 0,
#             'owner': '7150652@N02',
#             'secret': 'a98ed71d6c',
#             'server': '65535',
#             'tags': 'westlake losangeles california macarthurpark cityscape',
#             'title': 'MacArthur Park'},
#            {'accuracy': 0,
#             'context': 0,
#             'description': {'_content': 'Delivery amidst deliveries.'},
#             'farm': 66,
#             'id': '50219798942',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'latitude': 0,
#             'longitude': 0,
#             'owner': '189754776@N08',
#             'secret': 'fd82e4b9fb',
#             'server': '65535',
#             'tags': 'action california city man person phone portfolio sky '
#                     'street photography iphone swap meet westlake '
#                     'macarthurpark delivery flowers walking',
#             'title': '002-4'},
#            {'accuracy': '16',
#             'context': 0,
#             'description': {'_content': 'Westlake / MacArthur Park metro '
#                                         'station'},
#             'farm': 66,
#             'geo_is_contact': 0,
#             'geo_is_family': 0,
#             'geo_is_friend': 0,
#             'geo_is_public': 1,
#             'id': '49861807202',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'latitude': '34.055000',
#             'longitude': '-118.274167',
#             'owner': '22316914@N06',
#             'place_id': '',
#             'secret': 'ccec045e20',
#             'server': '65535',
#             'tags': 'losangeles ca california subway metro public tatyana '
#                     'transit mass red tile escalator exit entrance stairs '
#                     'reflection macarthurpark westlake '
#                     'someoneleftmycakeoutintherain dark light square flaneur '
#                     'flâneur lines',
#             'title': 'Subway',
#             'woeid': '8062690'},
#            {'accuracy': '16',
#             'context': 0,
#             'description': {'_content': 'MV2P_0798'},
#             'farm': 66,
#             'geo_is_contact': 0,
#             'geo_is_family': 0,
#             'geo_is_friend': 0,
#             'geo_is_public': 1,
#             'id': '49807593258',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'latitude': '34.059772',
#             'longitude': '-118.280000',
#             'owner': '15139867@N05',
#             'place_id': '',
#             'secret': 'b60723272a',
#             'server': '65535',
#             'tags': 'downtownlosangeles losangelesskyline macarthurpark '
#                     'twilight dtla',
#             'title': 'MacArthur Park, Downtown Los Angeles Skyline',
#             'woeid': '8062690'},
#            {'accuracy': '16',
#             'context': 0,
#             'description': {'_content': 'MV2P_0795'},
#             'farm': 66,
#             'geo_is_contact': 0,
#             'geo_is_family': 0,
#             'geo_is_friend': 0,
#             'geo_is_public': 1,
#             'id': '49808147591',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'latitude': '34.058600',
#             'longitude': '-118.276012',
#             'owner': '15139867@N05',
#             'place_id': '',
#             'secret': '868a4d0988',
#             'server': '65535',
#             'tags': 'downtownlosangeles losangelesskyline macarthurpark '
#                     'twilight dtla westlaketheatre',
#             'title': 'Westlake Theatre, Downtown Los Angeles Skyline',
#             'woeid': '8062690'},
#            {'accuracy': '16',
#             'context': 0,
#             'description': {'_content': 'MV2P_0799'},
#             'farm': 66,
#             'geo_is_contact': 0,
#             'geo_is_family': 0,
#             'geo_is_friend': 0,
#             'geo_is_public': 1,
#             'id': '49807593143',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'latitude': '34.057849',
#             'longitude': '-118.275764',
#             'owner': '15139867@N05',
#             'place_id': '',
#             'secret': 'cca7a03aa5',
#             'server': '65535',
#             'tags': 'downtownlosangeles losangelesskyline macarthurpark '
#                     'twilight dtla',
#             'title': 'Downtown Los Angeles Skyline',
#             'woeid': '8062690'},
#            {'accuracy': 0,
#             'context': 0,
#             'description': {'_content': 'Little Rock, Arkansas.  The problem '
#                                         'with this place is the ducks. They '
#                                         'walk all over the property and leave '
#                                         'their mess everywhere. If they got '
#                                         'rid of the ducks, it would be the '
#                                         'ideal spot.'},
#             'farm': 66,
#             'id': '49758256112',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'latitude': 0,
#             'longitude': 0,
#             'owner': '17027981@N02',
#             'secret': 'e323ddebe4',
#             'server': '65535',
#             'tags': 'macarthurpark littlerock arkanas scenic',
#             'title': 'MacArthur Park'},
#            {'accuracy': 0,
#             'context': 0,
#             'description': {'_content': ''},
#             'farm': 66,
#             'id': '49724386467',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'latitude': 0,
#             'longitude': 0,
#             'owner': '187355177@N04',
#             'secret': '47273ed3ae',
#             'server': '65535',
#             'tags': 'penguinvrmedia cityscape travel clouds aerialphotography '
#                     'drone skyline djimavic mavic2pro djimavic2 citylife '
#                     'aerialview flyingpenguin sandiego prequarantine '
#                     'presocialdistancing socalliving realestateagent '
#                     'sandiegorealestate travelcaptures dronepilot '
#                     'travelphotography macarthurpark downtownla '
#                     'downtownlosangeles',
#             'title': 'Downtown LA Macarthur Park'},
#            {'accuracy': 0,
#             'context': 0,
#             'description': {'_content': 'Just above the trees in MacArthur '
#                                         'park facing the city.'},
#             'farm': 66,
#             'id': '49724068091',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'latitude': 0,
#             'longitude': 0,
#             'owner': '187355177@N04',
#             'secret': '9da4e8aaa7',
#             'server': '65535',
#             'tags': 'macarthurpark downtown losangeles cityscape citylife '
#                     'skyline djimavic2pro drone travel westlaketheater clouds '
#                     'sky blue sun outside penguinvrmedia aerialphotography '
#                     'djimavic mavic2pro djimavic2 aerialview flyingpenguin '
#                     'sandiego prequarantine presocialdistancing socalliving '
#                     'realestateagent sandiegorealestate travelcaptures '
#                     'dronepilot travelphotography',
#             'title': 'Downtown LA Westlake Theater'},
#            {'accuracy': 0,
#             'context': 0,
#             'description': {'_content': 'Flat Panoramic of Los Angeles over '
#                                         'Macarthur Park.'},
#             'farm': 66,
#             'id': '49714664897',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'latitude': 0,
#             'longitude': 0,
#             'owner': '187355177@N04',
#             'secret': '58f3613566',
#             'server': '65535',
#             'tags': 'panorama macarthurpark downtownlosangeles cityscape '
#                     'citylife skyline djimavic2pro dronelife travel '
#                     'penguinvrmedia clouds aerialphotography drone djimavic '
#                     'mavic2pro djimavic2 aerialview flyingpenguin sandiego '
#                     'prequarantine presocialdistancing socalliving '
#                     'realestateagent sandiegorealestate travelcaptures '
#                     'dronepilot travelphotography',
#             'title': 'Panoramic of McArthur Park -  LA Skyline'},
#            {'accuracy': 0,
#             'context': 0,
#             'description': {'_content': ''},
#             'farm': 66,
#             'id': '49578461288',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'latitude': 0,
#             'longitude': 0,
#             'owner': '91538965@N00',
#             'secret': '1c885615e8',
#             'server': '65535',
#             'tags': 'derbyshire eastmidlandsdesigneroutlet macarthurpark '
#                     'photostream signs',
#             'title': '2020 01 Photostream (4)'},
#            {'accuracy': 0,
#             'context': 0,
#             'description': {'_content': 'Today...Lovey and I are at MacArthur '
#                                         'Park (formerly known as Westlake '
#                                         'Park) which is surrounded by 6th '
#                                         'Street, Alvarado, 7th Street and '
#                                         'S.Park View...and Wilshire runs '
#                                         "through the middle.  We've been "
#                                         "craving the #19 at Langer's...so we "
#                                         "thought we'd make a day of it and "
#                                         'enjoy the park and surroundings...   '
#                                         'Los Angeles, CA (Jan 4, 2013)\n'
#                                         '©2014 Rebecca Dru Photography All '
#                                         'Rights Reserved   <a '
#                                         'href="http://www.rebeccadru.com" '
#                                         'rel="noreferrer '
#                                         'nofollow">www.rebeccadru.com</a>    '
#                                         '<a '
#                                         'href="http://www.flickr.com/rebeccadru">www.flickr.com/rebeccadru</a>    '
#                                         '<a '
#                                         'href="http://www.twitter.com/rebeccadru" '
#                                         'rel="noreferrer '
#                                         'nofollow">www.twitter.com/rebeccadru</a>  '
#                                         '<a '
#                                         'href="http://www.facebook.com/rebeccadruphotography" '
#                                         'rel="noreferrer '
#                                         'nofollow">www.facebook.com/rebeccadruphotography</a>  '
#                                         '<a '
#                                         'href="http://www.instagram.com/rebeccadru" '
#                                         'rel="noreferrer '
#                                         'nofollow">www.instagram.com/rebeccadru</a>'},
#             'farm': 66,
#             'id': '49263122252',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'latitude': 0,
#             'longitude': 0,
#             'owner': '9561559@N04',
#             'secret': '7941f47b35',
#             'server': '65535',
#             'tags': 'rebeccadruphotography macarthurpark langersdeli '
#                     'olympicsign asburyapt parkplazahotel bpoeelks '
#                     'westlaketheatre jerryepstein losangeles '
#                     'historiclosangeles california usa',
#             'title': 'Lovey at the Fountain in MacArthur Park....'},
#            {'accuracy': 0,
#             'context': 0,
#             'description': {'_content': 'Today...Lovey and I are at MacArthur '
#                                         'Park (formerly known as Westlake '
#                                         'Park) which is surrounded by 6th '
#                                         'Street, Alvarado, 7th Street and '
#                                         'S.Park View...and Wilshire runs '
#                                         "through the middle.  We've been "
#                                         "craving the #19 at Langer's...so we "
#                                         "thought we'd make a day of it and "
#                                         'enjoy the park and surroundings...   '
#                                         'Los Angeles, CA (Jan 4, 2013)\n'
#                                         '©2014 Rebecca Dru Photography All '
#                                         'Rights Reserved   <a '
#                                         'href="http://www.rebeccadru.com" '
#                                         'rel="noreferrer '
#                                         'nofollow">www.rebeccadru.com</a>    '
#                                         '<a '
#                                         'href="http://www.flickr.com/rebeccadru">www.flickr.com/rebeccadru</a>    '
#                                         '<a '
#                                         'href="http://www.twitter.com/rebeccadru" '
#                                         'rel="noreferrer '
#                                         'nofollow">www.twitter.com/rebeccadru</a>  '
#                                         '<a '
#                                         'href="http://www.facebook.com/rebeccadruphotography" '
#                                         'rel="noreferrer '
#                                         'nofollow">www.facebook.com/rebeccadruphotography</a>  '
#                                         '<a '
#                                         'href="http://www.instagram.com/rebeccadru" '
#                                         'rel="noreferrer '
#                                         'nofollow">www.instagram.com/rebeccadru</a>'},
#             'farm': 66,
#             'id': '49263121967',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'latitude': 0,
#             'longitude': 0,
#             'owner': '9561559@N04',
#             'secret': '7742c6e5ca',
#             'server': '65535',
#             'tags': 'rebeccadruphotography macarthurpark langersdeli '
#                     'olympicsign asburyapt parkplazahotel bpoeelks '
#                     'westlaketheatre jerryepstein losangeles '
#                     'historiclosangeles california usa',
#             'title': 'Lovey at MacArthur Park'}],
#  'total': '4267'}

# %%
print(photos.keys())
# Out:
# dict_keys(['page', 'pages', 'perpage', 'total', 'photo'])

# %%
# We are interested in the key 'photo' since it has the 'tags' information that we are looking for
print(photos['photo'])
# Out:
# [{'id': '51132445243', 'owner': '59495466@N00', 'secret': '20dd9a0c5d', 'server': '65535', 'farm': 66, 'title': 'Across the Street 5', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'description': {'_content': 'Signed copies of my first book, titled LONESOME CITY, are available on my website at <a href="https://davidingraham.com/book" rel="noreferrer nofollow">davidingraham.com/book</a>'}, 'tags': 'bw blackwhite losangeles macarthurpark california city iphone iphoneography monochrome mobilephotography squareformat streetphotography urban urbanlifeinmetropolis', 'latitude': 0, 'longitude': 0, 'accuracy': 0, 'context': 0}, {'id': '50788075637', 'owner': '7150652@N02', 'secret': 'a63c59e03e', 'server': '65535', 'farm': 66, 'title': 'Westlake Theatre', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'description': {'_content': ''}, 'tags': 'macarthurpark westlake losangeles california westlaketheatre theater', 'latitude': 0, 'longitude': 0, 'accuracy': 0, 'context': 0}, {'id': '50788074892', 'owner': '7150652@N02', 'secret': '1f4c95d453', 'server': '65535', 'farm': 66, 'title': 'Harrison Gray Otis Statue', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'description': {'_content': ''}, 'tags': 'macarthurpark westlake losangeles california statue harrisongrayotis losangelestimes latimes', 'latitude': 0, 'longitude': 0, 'accuracy': 0, 'context': 0}, {'id': '50787969751', 'owner': '7150652@N02', 'secret': '07291826a5', 'server': '65535', 'farm': 66, 'title': 'MacArthur Park Community Arts Center', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'description': {'_content': ''}, 'tags': 'macarthurpark westlake losangeles california park pavilion spanishrevival', 'latitude': 0, 'longitude': 0, 'accuracy': 0, 'context': 0}, {'id': '50787969486', 'owner': '7150652@N02', 'secret': 'a58a5a791e', 'server': '65535', 'farm': 66, 'title': 'Elks Building', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'description': {'_content': ''}, 'tags': 'macarthurpark westlake losangeles california elksbuilding elks themacarthur hotel', 'latitude': 0, 'longitude': 0, 'accuracy': 0, 'context': 0}, {'id': '50787231266', 'owner': '7150652@N02', 'secret': 'dd83056b0f', 'server': '65535', 'farm': 66, 'title': 'Unite!', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'description': {'_content': ''}, 'tags': 'westlake losangeles california unionhall uclalaborcenter macarthurpark', 'latitude': 0, 'longitude': 0, 'accuracy': 0, 'context': 0}, {'id': '50787230516', 'owner': '7150652@N02', 'secret': '5cc2707a35', 'server': '65535', 'farm': 66, 'title': 'MacArthur Park', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'description': {'_content': ''}, 'tags': 'westlake losangeles california macarthurpark cityscape', 'latitude': 0, 'longitude': 0, 'accuracy': 0, 'context': 0}, {'id': '50787229971', 'owner': '7150652@N02', 'secret': 'a98ed71d6c', 'server': '65535', 'farm': 66, 'title': 'MacArthur Park', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'description': {'_content': ''}, 'tags': 'westlake losangeles california macarthurpark cityscape', 'latitude': 0, 'longitude': 0, 'accuracy': 0, 'context': 0}, {'id': '50219798942', 'owner': '189754776@N08', 'secret': 'fd82e4b9fb', 'server': '65535', 'farm': 66, 'title': '002-4', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'description': {'_content': 'Delivery amidst deliveries.'}, 'tags': 'action california city man person phone portfolio sky street photography iphone swap meet westlake macarthurpark delivery flowers walking', 'latitude': 0, 'longitude': 0, 'accuracy': 0, 'context': 0}, {'id': '49861807202', 'owner': '22316914@N06', 'secret': 'ccec045e20', 'server': '65535', 'farm': 66, 'title': 'Subway', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'description': {'_content': 'Westlake / MacArthur Park metro station'}, 'tags': 'losangeles ca california subway metro public tatyana transit mass red tile escalator exit entrance stairs reflection macarthurpark westlake someoneleftmycakeoutintherain dark light square flaneur flâneur lines', 'latitu ...

# %%
item1 = photos['photo'][0]  
print(item1)
# Out:
# {'id': '51132445243', 'owner': '59495466@N00', 'secret': '20dd9a0c5d', 'server': '65535', 'farm': 66, 'title': 'Across the Street 5', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'description': {'_content': 'Signed copies of my first book, titled LONESOME CITY, are available on my website at <a href="https://davidingraham.com/book" rel="noreferrer nofollow">davidingraham.com/book</a>'}, 'tags': 'bw blackwhite losangeles macarthurpark california city iphone iphoneography monochrome mobilephotography squareformat streetphotography urban urbanlifeinmetropolis', 'latitude': 0, 'longitude': 0, 'accuracy': 0, 'context': 0}

# %%
import pandas as pd
df_mcarthur = pd.DataFrame(photos['photo'])
df_mcarthur
# Out:
#              id          owner      secret server  farm  \
# 0   51132445243   59495466@N00  20dd9a0c5d  65535    66
# 1   50788075637    7150652@N02  a63c59e03e  65535    66
# 2   50788074892    7150652@N02  1f4c95d453  65535    66
# 3   50787969751    7150652@N02  07291826a5  65535    66
# 4   50787969486    7150652@N02  a58a5a791e  65535    66
# 5   50787231266    7150652@N02  dd83056b0f  65535    66
# 6   50787230516    7150652@N02  5cc2707a35  65535    66
# 7   50787229971    7150652@N02  a98ed71d6c  65535    66
# 8   50219798942  189754776@N08  fd82e4b9fb  65535    66
# 9   49861807202   22316914@N06  ccec045e20  65535    66
# 10  49807593258   15139867@N05  b60723272a  65535    66
# 11  49808147591   15139867@N05  868a4d0988  65535    66
# 12  49807593143   15139867@N05  cca7a03aa5  65535    66
# 13  49758256112   17027981@N02  e323ddebe4  65535    66
# 14  49724386467  187355177@N04  47273ed3ae  65535    66
# 15  49724068091  187355177@N04  9da4e8aaa7  65535    66
# 16  49714664897  187355177@N04  58f3613566  65535    66
# 17  49578461288   91538965@N00  1c885615e8  65535    66
# 18  49263122252    9561559@N04  7941f47b35  65535    66
# 19  49263121967    9561559@N04  7742c6e5ca  65535    66
#
#                                              title  ispublic  isfriend  \
# 0                              Across the Street 5         1         0
# 1                                 Westlake Theatre         1         0
# 2                        Harrison Gray Otis Statue         1         0
# 3             MacArthur Park Community Arts Center         1         0
# 4                                    Elks Building         1         0
# 5                                           Unite!         1         0
# 6                                   MacArthur Park         1         0
# 7                                   MacArthur Park         1         0
# 8                                            002-4         1         0
# 9                                           Subway         1         0
# 10    MacArthur Park, Downtown Los Angeles Skyline         1         0
# 11  Westlake Theatre, Downtown Los Angeles Skyline         1         0
# 12                    Downtown Los Angeles Skyline         1         0
# 13                                  MacArthur Park         1         0
# 14                      Downtown LA Macarthur Park         1         0
# 15                    Downtown LA Westlake Theater         1         0
# 16        Panoramic of McArthur Park -  LA Skyline         1         0
# 17                         2020 01 Photostream (4)         1         0
# 18     Lovey at the Fountain in MacArthur Park....         1         0
# 19                         Lovey at MacArthur Park         1         0
#
#     isfamily                                        description  ...  \
# 0          0  {'_content': 'Signed copies of my first book, ...  ...
# 1          0                                   {'_content': ''}  ...
# 2          0                                   {'_content': ''}  ...
# 3          0                                   {'_content': ''}  ...
# 4          0                                   {'_content': ''}  ...
# 5          0                                   {'_content': ''}  ...
# 6          0                                   {'_content': ''}  ...
# 7          0                                   {'_content': ''}  ...
# 8          0        {'_content': 'Delivery amidst deliveries.'}  ...
# 9          0  {'_content': 'Westlake / MacArthur Park metro ...  ...
# 10         0                          {'_content': 'MV2P_0798'}  ...
# 11         0                          {'_content': 'MV2P_0795'}  ...
# 12         0                          {'_content': 'MV2P_0799'}  ...
# 13         0  {'_content': 'Little Rock, Arkansas.  The prob...  ...
# 14         0                                   {'_content': ''}  ...
# 15         0  {'_content': 'Just above the trees in MacArthu...  ...
# 16         0  {'_content': 'Flat Panoramic of Los Angeles ov...  ...
# 17         0                                   {'_content': ''}  ...
# 18         0  {'_content': 'Today...Lovey and I are at MacAr...  ...
# 19         0  {'_content': 'Today...Lovey and I are at MacAr...  ...
#
#      latitude    longitude accuracy context  place_id    woeid geo_is_public  \
# 0           0            0        0       0       NaN      NaN           NaN
# 1           0            0        0       0       NaN      NaN           NaN
# 2           0            0        0       0       NaN      NaN           NaN
# 3           0            0        0       0       NaN      NaN           NaN
# 4           0            0        0       0       NaN      NaN           NaN
# 5           0            0        0       0       NaN      NaN           NaN
# 6           0            0        0       0       NaN      NaN           NaN
# 7           0            0        0       0       NaN      NaN           NaN
# 8           0            0        0       0       NaN      NaN           NaN
# 9   34.055000  -118.274167       16       0            8062690           1.0
# 10  34.059772  -118.280000       16       0            8062690           1.0
# 11  34.058600  -118.276012       16       0            8062690           1.0
# 12  34.057849  -118.275764       16       0            8062690           1.0
# 13          0            0        0       0       NaN      NaN           NaN
# 14          0            0        0       0       NaN      NaN           NaN
# 15          0            0        0       0       NaN      NaN           NaN
# 16          0            0        0       0       NaN      NaN           NaN
# 17          0            0        0       0       NaN      NaN           NaN
# 18          0            0        0       0       NaN      NaN           NaN
# 19          0            0        0       0       NaN      NaN           NaN
#
#     geo_is_contact  geo_is_friend  geo_is_family
# 0              NaN            NaN            NaN
# 1              NaN            NaN            NaN
# 2              NaN            NaN            NaN
# 3              NaN            NaN            NaN
# 4              NaN            NaN            NaN
# 5              NaN            NaN            NaN
# 6              NaN            NaN            NaN
# 7              NaN            NaN            NaN
# 8              NaN            NaN            NaN
# 9              0.0            0.0            0.0
# 10             0.0            0.0            0.0
# 11             0.0            0.0            0.0
# 12             0.0            0.0            0.0
# 13             NaN            NaN            NaN
# 14             NaN            NaN            NaN
# 15             NaN            NaN            NaN
# 16             NaN            NaN            NaN
# 17             NaN            NaN            NaN
# 18             NaN            NaN            NaN
# 19             NaN            NaN            NaN
#
# [20 rows x 21 columns]

# %%
print(df_mcarthur['tags'])
# Out:
# 0     bw blackwhite losangeles macarthurpark califor...
# 1     macarthurpark westlake losangeles california w...
# 2     macarthurpark westlake losangeles california s...
# 3     macarthurpark westlake losangeles california p...
# 4     macarthurpark westlake losangeles california e...
# 5     westlake losangeles california unionhall uclal...
# 6     westlake losangeles california macarthurpark c...
# 7     westlake losangeles california macarthurpark c...
# 8     action california city man person phone portfo...
# 9     losangeles ca california subway metro public t...
# 10    downtownlosangeles losangelesskyline macarthur...
# 11    downtownlosangeles losangelesskyline macarthur...
# 12    downtownlosangeles losangelesskyline macarthur...
# 13              macarthurpark littlerock arkanas scenic
# 14    penguinvrmedia cityscape travel clouds aerialp...
# 15    macarthurpark downtown losangeles cityscape ci...
# 16    panorama macarthurpark downtownlosangeles city...
# 17    derbyshire eastmidlandsdesigneroutlet macarthu...
# 18    rebeccadruphotography macarthurpark langersdel...
# 19    rebeccadruphotography macarthurpark langersdel...
# Name: tags, dtype: object

# %%
#The tags are in column 10
# Pull out the tags column into its own dataframe. Note: this dataframe is a Series (1 column)
df_mcarthur_tags = df_mcarthur.iloc[:, 10]
df_mcarthur_tags
type(df_mcarthur_tags)
# Out:
# pandas.core.series.Series

# %%
# Clean up the tags
# First, make sure the words are all lowercase for consistency
mcarthurDf_tags = df_mcarthur_tags.str.lower()
#type(mcarthurDf_tags)
print(mcarthurDf_tags)
# Out:
# 0     bw blackwhite losangeles macarthurpark califor...
# 1     macarthurpark westlake losangeles california w...
# 2     macarthurpark westlake losangeles california s...
# 3     macarthurpark westlake losangeles california p...
# 4     macarthurpark westlake losangeles california e...
# 5     westlake losangeles california unionhall uclal...
# 6     westlake losangeles california macarthurpark c...
# 7     westlake losangeles california macarthurpark c...
# 8     action california city man person phone portfo...
# 9     losangeles ca california subway metro public t...
# 10    downtownlosangeles losangelesskyline macarthur...
# 11    downtownlosangeles losangelesskyline macarthur...
# 12    downtownlosangeles losangelesskyline macarthur...
# 13              macarthurpark littlerock arkanas scenic
# 14    penguinvrmedia cityscape travel clouds aerialp...
# 15    macarthurpark downtown losangeles cityscape ci...
# 16    panorama macarthurpark downtownlosangeles city...
# 17    derbyshire eastmidlandsdesigneroutlet macarthu...
# 18    rebeccadruphotography macarthurpark langersdel...
# 19    rebeccadruphotography macarthurpark langersdel...
# Name: tags, dtype: object

# %%
tags_list = df_mcarthur["tags"].tolist()
print(tags_list)
type(tags_list)
# Out:
# ['bw blackwhite losangeles macarthurpark california city iphone iphoneography monochrome mobilephotography squareformat streetphotography urban urbanlifeinmetropolis', 'macarthurpark westlake losangeles california westlaketheatre theater', 'macarthurpark westlake losangeles california statue harrisongrayotis losangelestimes latimes', 'macarthurpark westlake losangeles california park pavilion spanishrevival', 'macarthurpark westlake losangeles california elksbuilding elks themacarthur hotel', 'westlake losangeles california unionhall uclalaborcenter macarthurpark', 'westlake losangeles california macarthurpark cityscape', 'westlake losangeles california macarthurpark cityscape', 'action california city man person phone portfolio sky street photography iphone swap meet westlake macarthurpark delivery flowers walking', 'losangeles ca california subway metro public tatyana transit mass red tile escalator exit entrance stairs reflection macarthurpark westlake someoneleftmycakeoutintherain dark light square flaneur flâneur lines', 'downtownlosangeles losangelesskyline macarthurpark twilight dtla', 'downtownlosangeles losangelesskyline macarthurpark twilight dtla westlaketheatre', 'downtownlosangeles losangelesskyline macarthurpark twilight dtla', 'macarthurpark littlerock arkanas scenic', 'penguinvrmedia cityscape travel clouds aerialphotography drone skyline djimavic mavic2pro djimavic2 citylife aerialview flyingpenguin sandiego prequarantine presocialdistancing socalliving realestateagent sandiegorealestate travelcaptures dronepilot travelphotography macarthurpark downtownla downtownlosangeles', 'macarthurpark downtown losangeles cityscape citylife skyline djimavic2pro drone travel westlaketheater clouds sky blue sun outside penguinvrmedia aerialphotography djimavic mavic2pro djimavic2 aerialview flyingpenguin sandiego prequarantine presocialdistancing socalliving realestateagent sandiegorealestate travelcaptures dronepilot travelphotography', 'panorama macarthurpark downtownlosangeles cityscape citylife skyline djimavic2pro dronelife travel penguinvrmedia clouds aerialphotography drone djimavic mavic2pro djimavic2 aerialview flyingpenguin sandiego prequarantine presocialdistancing socalliving realestateagent sandiegorealestate travelcaptures dronepilot travelphotography', 'derbyshire eastmidlandsdesigneroutlet macarthurpark photostream signs', 'rebeccadruphotography macarthurpark langersdeli olympicsign asburyapt parkplazahotel bpoeelks westlaketheatre jerryepstein losangeles historiclosangeles california usa', 'rebeccadruphotography macarthurpark langersdeli olympicsign asburyapt parkplazahotel bpoeelks westlaketheatre jerryepstein losangeles historiclosangeles california usa']
# list

# %%
#Join the tags into a single string 
tags_str = ''.join(tags_list)
type(tags_str)
# Out:
# str

# %%
#Tokenization refers to dividing the text into a sequence of words or sentences
# We want to divide the text into a sequence of words
# Use the textblob library to first transform the tags into a blob and then convert them into a series of words
#from textblob import TextBlob
#tags_str.words()

# %%
# Do a count of the words
# put this in a function so we can use it again later on
def countWords(wordlist):
    counts = {} # a dictionary to hold the counts
    for word in wordlist:
        lword = word.lower() # convert to lowercase
        if lword in counts:
            counts[lword] +=1
        else:
            # doesn't exist in the dictionary
            counts[lword] = 1

    # convert the dictionary to a dataframe
    # https://stackoverflow.com/questions/18837262/convert-python-dict-into-a-dataframe
    df = pd.DataFrame.from_dict(counts, orient='index', columns=['word_count'])

    # sort it by the word_count column
    df.sort_values('word_count', ascending=False, inplace=True)
    df.index.name = 'word'
    return df

# create a list of all the words, through splitting on the spaces
wordlist = eirtext_wordsonly.split()
df = countWords(wordlist)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-01844a14eb6d> in <module>
#      21
#      22 # create a list of all the words, through splitting on the spaces
# ---> 23 wordlist = eirtext_wordsonly.split()
#      24 df = countWords(wordlist)
#
# NameError: name 'eirtext_wordsonly' is not defined

# %%
#lemmatizing 
import nltk
nltk.download('stopwords')
nltk.download('punkt')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize, sent_tokenize
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/morganrogers/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/morganrogers/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
import re
swords = [re.sub(r"[^A-z\s]", "", sword) for sword in stopwords.words('english')]
wordlists = [[word for word in word_tokenize(tags_str.lower()) if word not in swords] for tag in tags_str]
print(wordlists[0])
# Out:
# ['bw', 'blackwhite', 'losangeles', 'macarthurpark', 'california', 'city', 'iphone', 'iphoneography', 'monochrome', 'mobilephotography', 'squareformat', 'streetphotography', 'urban', 'urbanlifeinmetropolismacarthurpark', 'westlake', 'losangeles', 'california', 'westlaketheatre', 'theatermacarthurpark', 'westlake', 'losangeles', 'california', 'statue', 'harrisongrayotis', 'losangelestimes', 'latimesmacarthurpark', 'westlake', 'losangeles', 'california', 'park', 'pavilion', 'spanishrevivalmacarthurpark', 'westlake', 'losangeles', 'california', 'elksbuilding', 'elks', 'themacarthur', 'hotelwestlake', 'losangeles', 'california', 'unionhall', 'uclalaborcenter', 'macarthurparkwestlake', 'losangeles', 'california', 'macarthurpark', 'cityscapewestlake', 'losangeles', 'california', 'macarthurpark', 'cityscapeaction', 'california', 'city', 'man', 'person', 'phone', 'portfolio', 'sky', 'street', 'photography', 'iphone', 'swap', 'meet', 'westlake', 'macarthurpark', 'delivery', 'flowers', 'walkinglosangeles', 'ca', 'california', 'subway', 'metro', 'public', 'tatyana', 'transit', 'mass', 'red', 'tile', 'escalator', 'exit', 'entrance', 'stairs', 'reflection', 'macarthurpark', 'westlake', 'someoneleftmycakeoutintherain', 'dark', 'light', 'square', 'flaneur', 'flâneur', 'linesdowntownlosangeles', 'losangelesskyline', 'macarthurpark', 'twilight', 'dtladowntownlosangeles', 'losangelesskyline', 'macarthurpark', 'twilight', 'dtla', 'westlaketheatredowntownlosangeles', 'losangelesskyline', 'macarthurpark', 'twilight', 'dtlamacarthurpark', 'littlerock', 'arkanas', 'scenicpenguinvrmedia', 'cityscape', 'travel', 'clouds', 'aerialphotography', 'drone', 'skyline', 'djimavic', 'mavic2pro', 'djimavic2', 'citylife', 'aerialview', 'flyingpenguin', 'sandiego', 'prequarantine', 'presocialdistancing', 'socalliving', 'realestateagent', 'sandiegorealestate', 'travelcaptures', 'dronepilot', 'travelphotography', 'macarthurpark', 'downtownla', 'downtownlosangelesmacarthurpark', 'downtown', 'losangeles', 'cityscape', 'citylife', 'skyline', 'djimavic2pro', 'drone', 'travel', 'westlaketheater', 'clouds', 'sky', 'blue', 'sun', 'outside', 'penguinvrmedia', 'aerialphotography', 'djimavic', 'mavic2pro', 'djimavic2', 'aerialview', 'flyingpenguin', 'sandiego', 'prequarantine', 'presocialdistancing', 'socalliving', 'realestateagent', 'sandiegorealestate', 'travelcaptures', 'dronepilot', 'travelphotographypanorama', 'macarthurpark', 'downtownlosangeles', 'cityscape', 'citylife', 'skyline', 'djimavic2pro', 'dronelife', 'travel', 'penguinvrmedia', 'clouds', 'aerialphotography', 'drone', 'djimavic', 'mavic2pro', 'djimavic2', 'aerialview', 'flyingpenguin', 'sandiego', 'prequarantine', 'presocialdistancing', 'socalliving', 'realestateagent', 'sandiegorealestate', 'travelcaptures', 'dronepilot', 'travelphotographyderbyshire', 'eastmidlandsdesigneroutlet', 'macarthurpark', 'photostream', 'signsrebeccadruphotography', 'macarthurpark', 'langersdeli', 'olympicsign', 'asburyapt', 'parkplazahotel', 'bpoeelks', 'westlaketheatre', 'jerryepstein', 'losangeles', 'historiclosangeles', 'california', 'usarebeccadruphotography', 'macarthurpark', 'langersdeli', 'olympicsign', 'asburyapt', 'parkplazahotel', 'bpoeelks', 'westlaketheatre', 'jerryepstein', 'losangeles', 'historiclosangeles', 'california', 'usa']

# %%
import gensim

# %%
dictionary = gensim.corpora.Dictionary(wordlists)
corpus = [dictionary.doc2bow(wl) for wl in wordlists]
model = gensim.models.LdaMulticore(corpus, id2word=dictionary, num_topics=10, alpha = 0.9, eta=0.9)

# %%
model.show_topics()
# Out:
# [(0,
#   '0.064*"macarthurpark" + 0.057*"losangeles" + 0.047*"california" + 0.037*"westlake" + 0.017*"djimavic" + 0.017*"aerialview" + 0.017*"citylife" + 0.016*"djimavic2" + 0.016*"drone" + 0.015*"presocialdistancing"'),
#  (1,
#   '0.069*"california" + 0.047*"macarthurpark" + 0.043*"losangeles" + 0.026*"westlake" + 0.017*"socalliving" + 0.017*"twilight" + 0.016*"cityscape" + 0.016*"travel" + 0.015*"citylife" + 0.015*"sandiegorealestate"'),
#  (2,
#   '0.058*"california" + 0.051*"losangeles" + 0.041*"macarthurpark" + 0.026*"westlake" + 0.018*"aerialphotography" + 0.018*"dronepilot" + 0.017*"clouds" + 0.017*"travelcaptures" + 0.017*"twilight" + 0.016*"prequarantine"'),
#  (3,
#   '0.059*"california" + 0.053*"losangeles" + 0.044*"macarthurpark" + 0.034*"westlake" + 0.018*"cityscape" + 0.017*"flyingpenguin" + 0.016*"realestateagent" + 0.016*"sandiegorealestate" + 0.014*"djimavic2" + 0.014*"djimavic"'),
#  (4,
#   '0.077*"macarthurpark" + 0.063*"california" + 0.051*"losangeles" + 0.024*"westlake" + 0.017*"mavic2pro" + 0.017*"westlaketheatre" + 0.015*"clouds" + 0.015*"flyingpenguin" + 0.015*"prequarantine" + 0.015*"presocialdistancing"'),
#  (5,
#   '0.067*"macarthurpark" + 0.056*"losangeles" + 0.040*"california" + 0.018*"westlake" + 0.018*"travelcaptures" + 0.017*"flyingpenguin" + 0.017*"cityscape" + 0.016*"sandiegorealestate" + 0.016*"aerialview" + 0.015*"socalliving"'),
#  (6,
#   '0.054*"macarthurpark" + 0.053*"losangeles" + 0.046*"california" + 0.026*"westlake" + 0.017*"dronepilot" + 0.017*"sandiego" + 0.017*"djimavic2" + 0.017*"flyingpenguin" + 0.016*"westlaketheatre" + 0.016*"skyline"'),
#  (7,
#   '0.055*"california" + 0.055*"macarthurpark" + 0.049*"losangeles" + 0.030*"westlake" + 0.018*"cityscape" + 0.018*"drone" + 0.016*"losangelesskyline" + 0.016*"sandiego" + 0.015*"citylife" + 0.015*"westlaketheatre"'),
#  (8,
#   '0.055*"macarthurpark" + 0.048*"california" + 0.043*"losangeles" + 0.023*"westlake" + 0.020*"citylife" + 0.019*"travel" + 0.018*"cityscape" + 0.017*"travelcaptures" + 0.016*"skyline" + 0.016*"djimavic"'),
#  (9,
#   '0.058*"california" + 0.055*"macarthurpark" + 0.043*"losangeles" + 0.024*"westlake" + 0.020*"dronepilot" + 0.016*"clouds" + 0.016*"prequarantine" + 0.016*"aerialphotography" + 0.015*"realestateagent" + 0.015*"sandiegorealestate"')]

# %%
model.show_topic(0)
# Out:
# [('macarthurpark', 0.06414207),
#  ('losangeles', 0.057426516),
#  ('california', 0.046859566),
#  ('westlake', 0.037247274),
#  ('djimavic', 0.017212328),
#  ('aerialview', 0.017029218),
#  ('citylife', 0.016787),
#  ('djimavic2', 0.016000912),
#  ('drone', 0.015981074),
#  ('presocialdistancing', 0.014985)]

# %%
#Visualize the tags
import pyLDAvis
import pyLDAvis.gensim_models   # note that in previous versions this was called pyLDAvis.gensim
pyLDAvis.enable_notebook()
pyLDAvis.gensim_models.prepare(model, corpus, dictionary)
# Out:
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 4      0.002648  0.002896       1        1  11.591616
# 0      0.001640  0.003122       2        1  11.139356
# 1     -0.002687  0.000082       3        1   9.934313
# 6      0.001273 -0.001801       4        1   9.899532
# 7      0.000200 -0.000968       5        1   9.824790
# 5      0.004730 -0.002811       6        1   9.764704
# 9     -0.000774 -0.000642       7        1   9.661599
# 8     -0.001543  0.002245       8        1   9.481850
# 3     -0.002244 -0.000702       9        1   9.397882
# 2     -0.003242 -0.001421      10        1   9.304359, topic_info=                  Term          Freq         Total Category  logprob  loglift
# 9           california  31217.000000  31217.000000  Default  30.0000  30.0000
# 55       macarthurpark  32439.000000  32439.000000  Default  29.0000  29.0000
# 117           westlake  15463.000000  15463.000000  Default  28.0000  28.0000
# 12           cityscape   8483.000000   8483.000000  Default  27.0000  27.0000
# 27          dronepilot   8199.000000   8199.000000  Default  26.0000  26.0000
# ..                 ...           ...           ...      ...      ...      ...
# 12           cityscape    672.364449   8483.424199  Topic10  -4.3748  -0.1604
# 119    westlaketheatre    613.695262   7766.934051  Topic10  -4.4661  -0.1634
# 11            citylife    612.030146   7883.569143  Topic10  -4.4689  -0.1811
# 39       flyingpenguin    585.426886   7939.001476  Topic10  -4.5133  -0.2325
# 53   losangelesskyline    564.688661   7910.377288  Topic10  -4.5494  -0.2650
#
# [554 rows x 6 columns], token_table=      Topic      Freq                               Term
# term
# 0         1  0.094366                  aerialphotography
# 0         2  0.100454                  aerialphotography
# 0         3  0.106299                  aerialphotography
# 0         4  0.088643                  aerialphotography
# 0         5  0.101306                  aerialphotography
# ...     ...       ...                                ...
# 120       6  0.098060  westlaketheatredowntownlosangeles
# 120       7  0.131606  westlaketheatredowntownlosangeles
# 120       8  0.101746  westlaketheatredowntownlosangeles
# 120       9  0.104327  westlaketheatredowntownlosangeles
# 120      10  0.076310  westlaketheatredowntownlosangeles
#
# [1210 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[5, 1, 2, 7, 8, 6, 10, 9, 4, 3])
